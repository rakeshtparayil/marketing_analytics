# %% [markdown]
# # Step1
# Loading the csv using pandas

# %%
# import Pandas
import pandas as pd

# read pets from csv
meta = pd.read_csv('./fb_circus.csv')
meta.head(5)
# Out:
#                                        Campaign name          Ad Set Name  \
# 0  MAI - Installs - DE - HH+CGN - AND - AO - V21....    Videos | 21.11.23
# 1  MAI - Installs - DE - HH+CGN - AND - AO - V21....    Videos | 21.11.23
# 2  MAI - Installs - DE - HH+CGN - AND - AO - V21....    Videos | 21.11.23
# 3  MAI - Installs - DE - HH+CGN - iOS - AO - V20....  Carousel | 20.11.23
# 4  MAI - Installs - DE - HH+CGN - iOS - AO - V20....  Carousel | 20.11.23
#
#           Day          Platform   Reach  Impressions  Frequency  \
# 0  2023-11-30  audience_network   132.0          287   2.174242
# 1  2023-11-30          facebook  2858.0         3386   1.184745
# 2  2023-11-30         instagram  3524.0         3938   1.117480
# 3  2023-11-30          facebook  2276.0         2607   1.145431
# 4  2023-11-30         instagram  9923.0        10595   1.067721
#
#    Amount spent (EUR)  CPM (cost per 1,000 impressions)  CPI  Clicks (all)  \
# ...
